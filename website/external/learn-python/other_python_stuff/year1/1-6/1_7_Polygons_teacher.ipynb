# %% [markdown]
# # Solutions: Polygon data

# %%
# import modules
import geopandas as gpd
import folium
import json
import branca

# %% [markdown]
# ## Polygon data formats

# %% [markdown]
# In this tutorial we will work with a shapefile of *polygons* representing municipalities in the provinces of Utrecht and Noord-Holland.

# %%
df = gpd.read_file('Data/polygon/Utrecht_NoordHolland.shp', geometry='geometry')

# %%
df.head()
# Out:
#    mzr_id             mzr_name  wnp_id        wnp_name  gem_id  \
# 0    7142  Wieringerwaard e.o.    3187  Wieringerwaard    1911
# 1    7108      Nibbixwoud e.o.    3153      Nibbixwoud     420
# 2    7103        Abbekerk e.o.    3147        Abbekerk     420
# 3    7065            Purmerend    3103       Purmerend     439
# 4    7472             Overveen    2653        Overveen     377
#
#          gem_name  prov_id      prov_name  inhabitant  address_co  NEAR_FID  \
# 0  Hollands Kroon       27  Noord-Holland      8020.0      3566.0     19990
# 1       Medemblik       27  Noord-Holland      4865.0      2340.0     15468
# 2       Medemblik       27  Noord-Holland      3985.0      1851.0     15389
# 3       Purmerend       27  Noord-Holland     79610.0     39860.0     14461
# 4     Bloemendaal       27  Noord-Holland      4170.0      1785.0     61524
#
#      NEAR_DIST                                           geometry
# 0  4006.929967  POLYGON ((120246.500 527259.100, 120274.000 52...
# 1   147.141043  POLYGON ((138590.100 523244.100, 137428.700 52...
# 2     0.000000  POLYGON ((132527.800 525385.900, 132537.400 52...
# 3     0.000000  POLYGON ((126892.300 498152.100, 126836.600 49...
# 4  2999.323658  POLYGON ((101658.600 488853.900, 101654.400 48...

# %% [markdown]
# Provinces are identified by the "prov_name" column. The different municipalities are identified by "gem_name" (gem stands for gemeente in Dutch). Municipalities can be further subdivided in multiple connected small cities and villages. The "inhabitant" column identifies the number of people living in each subdivision according to census. For instance, the gemeente of *Amsterdam* is made of 8 densely populated parts.

# %%
# show number of subdivision in each gemeente
df['gem_name'].value_counts()
# Out:
# Hollands Kroon    8
# Haarlemmermeer    8
# Amsterdam         8
# Schagen           7
# Zaanstad          7
#                  ..
# Veenendaal        1
# Renswoude         1
# Lopik             1
# Oostzaan          1
# Woudenberg        1
# Name: gem_name, Length: 74, dtype: int64

# %%
df.sort_values(by='inhabitant', ascending=False).head()
# Out:
#      mzr_id              mzr_name  wnp_id   wnp_name  gem_id   gem_name  \
# 61     7516  Amsterdam Nieuw-West    3594  Amsterdam     363  Amsterdam
# 65     7513        Amsterdam Zuid    3594  Amsterdam     363  Amsterdam
# 143    7512        Amsterdam West    3594  Amsterdam     363  Amsterdam
# 64     7514        Amsterdam Oost    3594  Amsterdam     363  Amsterdam
# 62     7515       Amsterdam Noord    3594  Amsterdam     363  Amsterdam
#
#      prov_id      prov_name  inhabitant  address_co  NEAR_FID  NEAR_DIST  \
# 61        27  Noord-Holland    149450.0     72496.0      9382        0.0
# 65        27  Noord-Holland    136200.0     85469.0      9481        0.0
# 143       27  Noord-Holland    132200.0     77902.0     61346        0.0
# 64        27  Noord-Holland    128655.0     72229.0       436        0.0
# 62        27  Noord-Holland     91275.0     47607.0     18742        0.0
#
#                                               geometry
# 61   POLYGON ((118127.700 483140.700, 117663.800 48...
# 65   POLYGON ((116411.200 482117.600, 116307.400 48...
# 143  POLYGON ((118582.700 484940.700, 118576.800 48...
# 64   POLYGON ((128038.400 486063.200, 128297.300 48...
# 62   POLYGON ((129812.200 488550.500, 129530.700 48...

# %% [markdown]
# Similar to what we saw for Points and LineStrings, a basic plot of each polygon can be obtained in the following fashion

# %%
df.geometry[0]

# %% [markdown]
# The `exterior` attribute contains geometrical information concerning the boundary of the polygon

# %%
df.geometry[0].exterior

# %% [markdown]
# The `area` attribute reports the area within the perimeter. A quick comparison for the [city of Utrecht](https://en.wikipedia.org/wiki/Utrecht) suggests these are pretty accurate.

# %%
# divide by 1000x1000 to have the value in sq. km

df[df['gem_name']=='Utrecht'].area.sum()/10**6
# Out:
# 99.21472385001576

# %% [markdown]
# ## Polygon data visualization

# %% [markdown]
# While not extremely sophisticated, `geopandas` offers some interesting plotting functionalities for polygons. Here is for instance a quick color-coded plot for the number of inhabitants within each polygon.

# %%
df.plot(column = 'inhabitant', cmap='YlOrRd', legend=True);

# %% [markdown]
# We resort to `folium` for better visualization. First, we transform our coordinate system to the standard "EPSG:4326" used by the library. We then plot a base map centered average latitude/longitude coordinates of the gemeente of Utrecht. After that, we plot all the polygons for this gemeente along with some informative pop-up windows.

# %%
df.to_crs(epsg=4326, inplace=True)

# %%
# select Utrecht rows
utrecht_sel = df['gem_name']=='Utrecht'

# compute average coordinates
avg_x_coord = (df[utrecht_sel].bounds.minx+df[utrecht_sel].bounds.maxx)/2
avg_y_coord = (df[utrecht_sel].bounds.miny+df[utrecht_sel].bounds.maxy)/2

# %%
# create folium base map
poly_map = folium.Map(
    location=[avg_y_coord.mean(),avg_x_coord.mean()],    
    zoom_start=12
)

# visualize Utrecht polygons
utrecht_gjson = folium.features.GeoJson(
    df[utrecht_sel],
).add_to(poly_map)

# add informative pop-up windows
folium.features.GeoJsonPopup(
    fields=['mzr_name', 'gem_name', 'inhabitant'],
    aliases=['Location', 'Municipality', 'Population'],
    labels=True
).add_to(utrecht_gjson)

# visualize map
poly_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14da9783ea1c81efec54d90dda456c16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14da9783ea1c81efec54d90dda456c16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_14da9783ea1c81efec54d90dda456c16 = L.map(
#                 &quot;map_14da9783ea1c81efec54d90dda456c16&quot;,
#                 {
#                     center: [52.08890013323414, 5.094549130272334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5ef01ab4448f1bbfeb3aeb8369e6ae8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_14da9783ea1c81efec54d90dda456c16);
#
#
#
#         function geo_json_d7af00fa2c9cf7312612648b9e37854d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d7af00fa2c9cf7312612648b9e37854d = L.geoJson(null, {
#                 onEachFeature: geo_json_d7af00fa2c9cf7312612648b9e37854d_onEachFeature,
#
#         });
#
#         function geo_json_d7af00fa2c9cf7312612648b9e37854d_add (data) {
#             geo_json_d7af00fa2c9cf7312612648b9e37854d
#                 .addData(data)
#                 .addTo(map_14da9783ea1c81efec54d90dda456c16);
#         }
#             geo_json_d7af00fa2c9cf7312612648b9e37854d_add({&quot;bbox&quot;: [4.969929984313716, 52.02622268470804, 5.195201227946955, 52.14208564653501], &quot;features&quot;: [{&quot;bbox&quot;: [5.098320575219565, 52.07692654759196, 5.129599762981266, 52.097929484204464], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.122378996207288, 52.078820518676864], [5.121764358040708, 52.07792032810782], [5.118542269959225, 52.07909046816961], [5.114648296364693, 52.07773421590515], [5.10941207537388, 52.07692654759196], [5.10874962915729, 52.078833155704544], [5.106417716041473, 52.08082028318005], [5.103005365875641, 52.08267893147952], [5.098320575219565, 52.08498107749922], [5.100746604691747, 52.08866491838062], [5.104589788183782, 52.090061052625245], [5.105293990345955, 52.091539478381115], [5.107094670765152, 52.0922313570443], [5.105941869085527, 52.09339616276845], [5.108987831240759, 52.09472103920645], [5.109562329586283, 52.09550075951181], [5.1112341993527455, 52.09605565223555], [5.1135746981748635, 52.09657702109224], [5.115692593716095, 52.09651450603852], [5.119110946904442, 52.09642076201643], [5.120449017650678, 52.097179692027915], [5.122362521362792, 52.09688739913609], [5.124034068062838, 52.097532888441144], [5.126969492942049, 52.097929484204464], [5.126340434843158, 52.09618800702705], [5.126507701077612, 52.09503161404697], [5.127202027259471, 52.09458104768331], [5.12866389030155, 52.09362973005754], [5.127179539573646, 52.092675529553574], [5.127515379426945, 52.09037532574119], [5.129280362317251, 52.08946421472505], [5.128595090527187, 52.08735591103525], [5.129599762981266, 52.085434663554075], [5.1254058119541455, 52.08133675077424], [5.124198035942163, 52.081310693636254], [5.122378996207288, 52.078820518676864]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;53&quot;, &quot;properties&quot;: {&quot;NEAR_DIST&quot;: 1283.47349347, &quot;NEAR_FID&quot;: 36792, &quot;address_co&quot;: 13743.0, &quot;gem_id&quot;: 344, &quot;gem_name&quot;: &quot;Utrecht&quot;, &quot;inhabitant&quot;: 23150.0, &quot;mzr_id&quot;: 7520, &quot;mzr_name&quot;: &quot;Utrecht Centrum&quot;, &quot;prov_id&quot;: 26, &quot;prov_name&quot;: &quot;Utrecht&quot;, &quot;wnp_id&quot;: 3295, &quot;wnp_name&quot;: &quot;Utrecht&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [4.969929984313716, 52.02622268470804, 5.076237859088007, 52.14208564653501], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.017372143167775, 52.06099480087988], [5.01734580723729, 52.06100550399757], [5.017224364221069, 52.0610554563801], [5.017044475605404, 52.06111960609285], [5.017000596992261, 52.06113564691372], [5.0171454176561285, 52.06125654296352], [5.017159895308184, 52.0612691718334], [5.017386459015304, 52.061556604951456], [5.017625121450331, 52.06179194431716], [5.017804096977592, 52.06201541150613], [5.017964651451559, 52.062174106050165], [5.017403754036632, 52.06228739544592], [5.015361466589534, 52.06272947715127], [5.013026802228962, 52.06325328642464], [5.011943040075217, 52.0634592639835], [5.01120031573391, 52.

# %% [markdown]
# ### Tooltip

# %% [markdown]
# Clicking on each displayed element to retrieve information can be tedious; `folium` offers an interesting alternative with the `Tooltip` feature. By using `Tooltip` we can easily show information when hovering the mouse pointer on each polygon.

# %%
# create folium base map
poly_map = folium.Map(
    location=[avg_y_coord.mean(),avg_x_coord.mean()],    
    zoom_start=12
)

# visualize Utrecht polygons
utrecht_gjson = folium.features.GeoJson(
    df[utrecht_sel],
).add_to(poly_map)

# add tooltip functionality
folium.features.GeoJsonTooltip(
    fields=['mzr_name', 'gem_name', 'inhabitant'],
    aliases=['Location', 'Municipality', 'Population']
).add_to(utrecht_gjson)

# visualize map
poly_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_387935ede7c775744084a3aa7b34126c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_387935ede7c775744084a3aa7b34126c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_387935ede7c775744084a3aa7b34126c = L.map(
#                 &quot;map_387935ede7c775744084a3aa7b34126c&quot;,
#                 {
#                     center: [52.08890013323414, 5.094549130272334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f27cb5f01b5a6481e70434c8bc443023 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_387935ede7c775744084a3aa7b34126c);
#
#
#
#         function geo_json_8bdbd45f7e8093766504b9054730f116_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8bdbd45f7e8093766504b9054730f116 = L.geoJson(null, {
#                 onEachFeature: geo_json_8bdbd45f7e8093766504b9054730f116_onEachFeature,
#
#         });
#
#         function geo_json_8bdbd45f7e8093766504b9054730f116_add (data) {
#             geo_json_8bdbd45f7e8093766504b9054730f116
#                 .addData(data)
#                 .addTo(map_387935ede7c775744084a3aa7b34126c);
#         }
#             geo_json_8bdbd45f7e8093766504b9054730f116_add({&quot;bbox&quot;: [4.969929984313716, 52.02622268470804, 5.195201227946955, 52.14208564653501], &quot;features&quot;: [{&quot;bbox&quot;: [5.098320575219565, 52.07692654759196, 5.129599762981266, 52.097929484204464], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.122378996207288, 52.078820518676864], [5.121764358040708, 52.07792032810782], [5.118542269959225, 52.07909046816961], [5.114648296364693, 52.07773421590515], [5.10941207537388, 52.07692654759196], [5.10874962915729, 52.078833155704544], [5.106417716041473, 52.08082028318005], [5.103005365875641, 52.08267893147952], [5.098320575219565, 52.08498107749922], [5.100746604691747, 52.08866491838062], [5.104589788183782, 52.090061052625245], [5.105293990345955, 52.091539478381115], [5.107094670765152, 52.0922313570443], [5.105941869085527, 52.09339616276845], [5.108987831240759, 52.09472103920645], [5.109562329586283, 52.09550075951181], [5.1112341993527455, 52.09605565223555], [5.1135746981748635, 52.09657702109224], [5.115692593716095, 52.09651450603852], [5.119110946904442, 52.09642076201643], [5.120449017650678, 52.097179692027915], [5.122362521362792, 52.09688739913609], [5.124034068062838, 52.097532888441144], [5.126969492942049, 52.097929484204464], [5.126340434843158, 52.09618800702705], [5.126507701077612, 52.09503161404697], [5.127202027259471, 52.09458104768331], [5.12866389030155, 52.09362973005754], [5.127179539573646, 52.092675529553574], [5.127515379426945, 52.09037532574119], [5.129280362317251, 52.08946421472505], [5.128595090527187, 52.08735591103525], [5.129599762981266, 52.085434663554075], [5.1254058119541455, 52.08133675077424], [5.124198035942163, 52.081310693636254], [5.122378996207288, 52.078820518676864]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;53&quot;, &quot;properties&quot;: {&quot;NEAR_DIST&quot;: 1283.47349347, &quot;NEAR_FID&quot;: 36792, &quot;address_co&quot;: 13743.0, &quot;gem_id&quot;: 344, &quot;gem_name&quot;: &quot;Utrecht&quot;, &quot;inhabitant&quot;: 23150.0, &quot;mzr_id&quot;: 7520, &quot;mzr_name&quot;: &quot;Utrecht Centrum&quot;, &quot;prov_id&quot;: 26, &quot;prov_name&quot;: &quot;Utrecht&quot;, &quot;wnp_id&quot;: 3295, &quot;wnp_name&quot;: &quot;Utrecht&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [4.969929984313716, 52.02622268470804, 5.076237859088007, 52.14208564653501], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[5.017372143167775, 52.06099480087988], [5.01734580723729, 52.06100550399757], [5.017224364221069, 52.0610554563801], [5.017044475605404, 52.06111960609285], [5.017000596992261, 52.06113564691372], [5.0171454176561285, 52.06125654296352], [5.017159895308184, 52.0612691718334], [5.017386459015304, 52.061556604951456], [5.017625121450331, 52.06179194431716], [5.017804096977592, 52.06201541150613], [5.017964651451559, 52.062174106050165], [5.017403754036632, 52.06228739544592], [5.015361466589534, 52.06272947715127], [5.013026802228962, 52.06325328642464], [5.011943040075217, 52.0634592639835], [5.01120031573391, 52.06368

# %% [markdown]
# ### Choropleth

# %% [markdown]
# While prettier, the maps above are somewhat less informative than the `geopandas` visualization on the distribution of inhabitants across the municipalities.
#
# These type of maps are known as [choropleth map](https://en.wikipedia.org/wiki/Choropleth_map). Choropleth maps are statistical thematic maps that use color coding to provide aggregate summary of a geographic characteristic within spatial enumeration units, such as totals (e.g. total population) or averages (e.g. population density or per-capita income). Choropleth maps provide an easy way to visualize how a variable varies across a geographic area or show the level of variability within a region.
#
# [There are many ways](https://towardsdatascience.com/creating-choropleth-maps-with-pythons-folium-library-cfacfb40f56a) to create such visualizations with `folium`. Below we provide a solution that exploits `style_functions` and the `branca` library as introduced in the [previous notebook](./2_Lines.ipynb) on `LineStrings`.

# %%
# create learn colormap interpolating 3 colors
colors = branca.colormap.LinearColormap(
    ['green', 'yellow', 'red'], vmin=df.inhabitant.min(), vmax=df.inhabitant.max())

# %%
# define style function
def population_choropleth(row):
    return {
        "fillColor": colors(row['properties']['inhabitant']),
        "color": "white",
        "weight": 1,
        "fillOpacity": 0.75,
    }

# %%
# create base map
poly_map = folium.Map(
    location=[avg_y_coord.mean(),avg_x_coord.mean()],    
    zoom_start=8
)

# overlay choropleth
gjson = folium.features.GeoJson(
    df,
    style_function=population_choropleth,
    ).add_to(poly_map)

# add colormap to the map
poly_map.add_child(colors)

# display
poly_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4819f37e3e79422a8a986ecd1ad58e1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4819f37e3e79422a8a986ecd1ad58e1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_4819f37e3e79422a8a986ecd1ad58e1d = L.map(
#                 &quot;map_4819f37e3e79422a8a986ecd1ad58e1d&quot;,
#                 {
#                     center: [52.08890013323414, 5.094549130272334],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0381c1514ac89b751b969f7618703c4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4819f37e3e79422a8a986ecd1ad58e1d);
#
#
#         function geo_json_0dd6401433ecd3fbe2839c1bc89d95b5_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;44&quot;: case &quot;120&quot;: case &quot;194&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#1b8e00ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;79&quot;: case &quot;89&quot;: case &quot;113&quot;: case &quot;198&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#108800ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;98&quot;: case &quot;138&quot;: case &quot;169&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#0d8700ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#ffef00ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;22&quot;: case &quot;26&quot;: case &quot;80&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#0e8700ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;14&quot;: case &quot;119&quot;: case &quot;125&quot;: case &quot;159&quot;: case &quot;193&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#0c8600ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;6&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#2b9600ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;7&quot;: case &quot;39&quot;: case &quot;52&quot;: case &quot;90&quot;: case &quot;150&quot;: case &quot;173&quot;: case &quot;203&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#158b00ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;8&quot;: case &quot;187&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#249200ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;9&quot;: case &quot;191&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#4ba500ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;10&quot;: case &quot;33&quot;: case &quot;161&quot;: case &quot;175&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#118900ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;11&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#379c00ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;12&quot;: case &quot;35&quot;: case &quot;168&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#0b8600ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#62b100ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;16&quot;: case &quot;38&quot;: case &quot;158&quot;: case &quot;190&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#1e8f00ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;17&quot;: case &quot;24&quot;: case &quot;95&quot;: case &quot;128&quot;: case &quot;147&quot;: case &quot;167&quot;:
#                     return {&quot;color&quot

# %% [markdown]
# ### Exercise

# %% [markdown]
# You are given a geospatial dataset for the provinces in Vietnam. The dataset contains the polygon geometry along with information on the name of the province, whether it is a city or not, and its surface area in sq. km.

# %%
gdf_vietnam = gpd.read_file('./Data/case_study/vietnam_bound.geojson')
gdf_vietnam['area_sqkm']=round(gdf_vietnam.to_crs(epsg=9215).area/10**6)
gdf_vietnam = gdf_vietnam[['VARNAME_1','ENGTYPE_1','area_sqkm','geometry']]
gdf_vietnam.columns = ['name','type','area_sqkm','geometry']

# %%
gdf_vietnam.plot(column='type');

# %% [markdown]
# Your task is to use `folium` as shown earlier in the notebook to display a Cloropeth map for the Vietnam provinces, where:
#
# 1. The map is centered on Hanoi, e.g. `latitude = 21.03 N`, `longitude = 105.8 E`;
# 2. The Cloropeth shows the surface area of each province;
# 3. Colors are assigned using a linear `branca` colormap scaled between the minimum and the maximum;
# 4. The colorbar is visible on the map;
# 5. The map has a `Tooltip` feature that shows all information available on the province.

# %% [markdown]
# #### Solution

# %%
# create colormap
colors = branca.colormap.LinearColormap(['gray','blue','purple'], 
                                         vmin=gdf_vietnam['area_sqkm'].min(), vmax=gdf_vietnam['area_sqkm'].max())

# define style function
def area_choropleth(row):
    return {
        "fillColor": colors(row['properties']['area_sqkm']),
        "color": "white",
        "weight": 1,
        "fillOpacity": 0.75,
    }

# create base map
vtn_map = folium.Map(
    location=[21.03, 105.8],
    zoom_start=5
)

# overlay choropleth
vtn_gjson = folium.features.GeoJson(
    gdf_vietnam,
    style_function=area_choropleth,
    ).add_to(vtn_map)

# add tooltip functionality
folium.features.GeoJsonTooltip(
    fields=['name','type','area_sqkm']
).add_to(vtn_gjson)

# add colormap to the map
vtn_map.add_child(colors)

# display
vtn_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed408a240b665f0634eb6ff2b16f6239 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed408a240b665f0634eb6ff2b16f6239&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_ed408a240b665f0634eb6ff2b16f6239 = L.map(
#                 &quot;map_ed408a240b665f0634eb6ff2b16f6239&quot;,
#                 {
#                     center: [21.03, 105.8],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b8c916993952f91a4bfef9863ff5ecf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ed408a240b665f0634eb6ff2b16f6239);
#
#
#         function geo_json_27f24c9fe9e5cea374c5f6da245c18e9_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;539&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#4949b7ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#5959a6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#4343bcff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#3434cbff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;4&quot;: case &quot;287&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#73738dff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;5&quot;: case &quot;1249&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#5c5ca4ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#62629dff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;64&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#2222deff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;66&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#5656aaff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;67&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#1515eaff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;80&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#0505faff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;81&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#6a6a96ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;89&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#2f2fd0ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;90&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#1818e8ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;91&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#4a00b6ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;92&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quot;fillColor&quot;: &quot;#1b1be5ff&quot;, &quot;fillOpacity&quot;: 0.75, &quot;weight&quot;: 1};
#                 case &quot;93&quot;: case &quot;1250&quot;:
#                     return {&quot;color&quot;: &quot;white&quot;, &quo
